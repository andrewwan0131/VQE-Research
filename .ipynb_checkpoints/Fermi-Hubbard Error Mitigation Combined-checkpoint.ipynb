# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import qiskit
from qiskit import *
from math import pi
from qiskit.test.mock import FakeLondon
from qiskit import Aer
from qiskit import aqua
from NoiseModel import generateDepolarizingError, generateRelaxationError, generateNoiseModel
from qiskit.visualization import plot_histogram
import math
import cmath

t=1
U=1
machine = FakeLondon()
simulator = Aer.get_backend('qasm_simulator')
noise_model = generateNoiseModel(machine, coherent = False, incoherent = False, readout= True)
# Out:
# Original: 0.01 0.050000000000000044
# Reverse: 0.01 0.050000000000000044
# Original: 0.02 0.07666666666666666
# Reverse: 0.02 0.07666666666666666
# Original: 0.14 0.18999999999999995
# Reverse: 0.14 0.18999999999999995
# Original: 0.0033333333333332993 0.03
# Reverse: 0.0033333333333332993 0.03
# Original: 0.006666666666666667 0.043333333333333335
# Reverse: 0.006666666666666667 0.043333333333333335

# %%
IBMQ.save_account(token="4d27cf4fc846df164ebc35734c48c5c21c3e3d8698af0b25c0a105dd651cd6245349d7f232c3b20c43f3650e0a8c87dcc098e76fcd31c182c0778441d4d975fd", hub="ibm-q-education", group="rutgers-2", project="vqe-research", overwrite=True)
IBMQ.load_account()
provider=IBMQ.get_provider("ibm-q-education")

# %%
#dummy parameters
phi = pi/4
theta = pi/4

# %% [markdown]
# # Circuit

# %% [markdown]
# Lets make a function out of this which takes in a value for gamma and outputs the circuit with gamma = that value

# %%
def get_hopping_circ(phi, theta):
    
    qreg_q = QuantumRegister(8, 'q')
    creg_c = ClassicalRegister(8, 'c')
    circuit = QuantumCircuit(qreg_q, creg_c)

    # Initialization
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    circuit.cry(-pi/2, qreg_q[1], qreg_q[0])
    circuit.cry(-pi/2, qreg_q[3], qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])

    # Barrier
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])

    # Ansatz
    circuit.crz(phi, qreg_q[2], qreg_q[0])
    circuit.crz(phi, qreg_q[3], qreg_q[1])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    circuit.crx(theta, qreg_q[1], qreg_q[0])
    circuit.crx(theta, qreg_q[3], qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])


    # Barrier
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])

    # Diagonalization
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    circuit.ch(qreg_q[1], qreg_q[0])
    circuit.ch(qreg_q[3], qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    
    # Barrier
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    
    circuit.cx(qreg_q[0], qreg_q[4])
    circuit.cx(qreg_q[1], qreg_q[5])
    circuit.cx(qreg_q[2], qreg_q[6])
    circuit.cx(qreg_q[3], qreg_q[7])
    circuit.x(qreg_q[4])
    circuit.x(qreg_q[5])
    circuit.x(qreg_q[6])
    circuit.x(qreg_q[7])
    
    # Measurement
    circuit.measure(qreg_q[0], creg_c[0])
    circuit.measure(qreg_q[1], creg_c[1])
    circuit.measure(qreg_q[2], creg_c[2])
    circuit.measure(qreg_q[3], creg_c[3])
    circuit.measure(qreg_q[4], creg_c[4])
    circuit.measure(qreg_q[5], creg_c[5])
    circuit.measure(qreg_q[6], creg_c[6])
    circuit.measure(qreg_q[7], creg_c[7])
    
    return circuit

# %%
get_hopping_circ(phi, theta).draw('mpl')

# %%
def get_onsite_circ(phi, theta):
    
    qreg_q = QuantumRegister(8, 'q')
    creg_c = ClassicalRegister(8, 'c')
    circuit = QuantumCircuit(qreg_q, creg_c)

    # Initialization
    circuit.x(qreg_q[0])
    circuit.x(qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    circuit.cry(-pi/2, qreg_q[1], qreg_q[0])
    circuit.cry(-pi/2, qreg_q[3], qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])

    # Barrier
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])

    # Ansatz
    circuit.crz(phi, qreg_q[2], qreg_q[0])
    circuit.crz(phi, qreg_q[3], qreg_q[1])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])
    circuit.crx(theta, qreg_q[1], qreg_q[0])
    circuit.crx(theta, qreg_q[3], qreg_q[2])
    circuit.cx(qreg_q[0], qreg_q[1])
    circuit.cx(qreg_q[2], qreg_q[3])


    # Barrier
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3])
    
    circuit.cx(qreg_q[0], qreg_q[4])
    circuit.cx(qreg_q[1], qreg_q[5])
    circuit.cx(qreg_q[2], qreg_q[6])
    circuit.cx(qreg_q[3], qreg_q[7])
    circuit.x(qreg_q[4])
    circuit.x(qreg_q[5])
    circuit.x(qreg_q[6])
    circuit.x(qreg_q[7])
    
    # Measurement
    circuit.measure(qreg_q[0], creg_c[0])
    circuit.measure(qreg_q[1], creg_c[1])
    circuit.measure(qreg_q[2], creg_c[2])
    circuit.measure(qreg_q[3], creg_c[3])
    circuit.measure(qreg_q[4], creg_c[4])
    circuit.measure(qreg_q[5], creg_c[5])
    circuit.measure(qreg_q[6], creg_c[6])
    circuit.measure(qreg_q[7], creg_c[7])
    
    return circuit

# %%
get_onsite_circ(phi, theta).draw('mpl')

# %% [markdown]
# # Measuring the circuit
# We're gonna define some objective function/energy that has to be calculated using the resulting counts from the function

# %%
def get_hopping_counts(arr):
    circ = get_hopping_circ(arr[0], arr[1])
    backend = provider.get_backend('ibm_lagos')
    job = execute(circ, backend, shots = 8192)
    counts = job.result().get_counts()
    return counts

# %%
def get_onsite_counts(arr):
    circ = get_onsite_circ(arr[0], arr[1])
    backend = provider.get_backend('ibm_lagos')
    job = execute(circ, backend, shots = 8192)
    counts = job.result().get_counts()
    return counts

# %%
def new_counts(counts):
    counts_new = {}
     
    for key in counts:
        if counts_new.get(key[4:8]) != None:
            counts_new[key[4:8]]=counts_new[key[4:8]]+counts.get(key)
        else:
            counts_new[key[4:8]] = counts.get(key)

    return counts_new

# %%
def new_counts_mitigated(counts):
    counts_new = {}
     
    for key in counts:
        if key[7]==key[3] or key[6]==key[2] or key[5]==key[1] or key[4]==key[0]:
            counts[key] = 0
        if counts_new.get(key[4:8]) != None:
            counts_new[key[4:8]]=counts_new[key[4:8]]+counts.get(key)
        else:
            counts_new[key[4:8]] = counts.get(key)

    return counts_new

# %%
def find_energy(counts1, counts2):
    energy1 = -t*((counts1.get('1010', 0)+counts1.get('0110', 0))-(counts1.get('1001', 0)+counts1.get('0101', 0))+(counts1.get('1010', 0)+counts1.get('1001', 0))-(counts1.get('0110', 0)+counts1.get('0101', 0)))/sum(counts1.values())
    energy2 = U*(counts2.get('1010', 0)+counts2.get('0101', 0))/sum(counts2.values())
    return energy1 + energy2

# %% [markdown]
# ##### Ready to Optimize

# %%
def f1(arr):
    counts1 = get_hopping_counts(arr)
    counts2 = get_onsite_counts(arr)
    counts1_new = new_counts(counts1)
    counts2_new = new_counts(counts2)
    return find_energy(counts1_new, counts2_new)

# %%
def f2(arr):
    counts1 = get_hopping_counts(arr)
    counts2 = get_onsite_counts(arr)
    counts1_new = new_counts_mitigated(counts1)
    counts2_new = new_counts_mitigated(counts2)
    return find_energy(counts1_new, counts2_new)

# %%
from scipy.optimize import minimize
import numpy as np
import random
from scipy.optimize import minimize
from qiskit.algorithms.optimizers import SPSA
import numpy as np
import random

# %%
iterations1 = []
parameters1 = []
values1 = []
iterations2 = []
parameters2 = []
values2 = []

def callback_fn1(iteration, parameter, value, stepsize, accepted):
    if (accepted):
        iterations1.append(iteration/3)
        parameters1.append(parameter)
        values1.append(value)
        
def callback_fn2(iteration, parameter, value, stepsize, accepted):
    if (accepted):
        iterations2.append(iteration/3)
        parameters2.append(parameter)
        values2.append(value)
    
    
true = (-math.sqrt(17)+1)/2
    
spsa1 = SPSA(maxiter=10, callback=callback_fn1)
param1, value1, nefv1 = spsa1.optimize(num_vars=2, objective_function=f1, gradient_function=None, variable_bounds=None, initial_point=np.array([0, 0]))

spsa2 = SPSA(maxiter=10, callback=callback_fn2)
param2, value2, nefv2 = spsa2.optimize(num_vars=2, objective_function=f2, gradient_function=None, variable_bounds=None, initial_point=np.array([0, 0]))

phi1 = param1[0]
theta1 = param1[1]
energy_diff1 = value1-true

phi2 = param2[0]
theta2 = param2[1]
energy_diff2 = value2-true
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# Input In [17], in <module>
#      21 true = (-math.sqrt(17)+1)/2
#      23 spsa1 = SPSA(maxiter=10, callback=callback_fn1)
# ---> 24 param1, value1, nefv1 = spsa1.optimize(num_vars=2, objective_function=f1, gradient_function=None, variable_bounds=None, initial_point=np.array([0, 0]))
#      26 spsa2 = SPSA(maxiter=10, callback=callback_fn2)
#      27 param2, value2, nefv2 = spsa2.optimize(num_vars=2, objective_function=f2, gradient_function=None, variable_bounds=None, initial_point=np.array([0, 0]))
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\algorithms\optimizers\spsa.py:652, in SPSA.optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     644 def optimize(
#     645     self,
#     646     num_vars,
#    (...)
#     650     initial_point=None,
#     651 ):
# --> 652     result = self.minimize(objective_function, initial_point)
#     653     return result.x, result.fun, result.nfev
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\algorithms\optimizers\spsa.py:511, in SPSA.minimize(self, fun, x0, jac, bounds)
#     501 def minimize(
#     502     self,
#     503     fun: Callable[[POINT], float],
#    (...)
#     508     # ensure learning rate and perturbation are correctly set: either none or both
#     509     # this happens only here because for the calibration the loss function is required
#     510     if self.learning_rate is None and self.perturbation is None:
# --> 511         get_eta, get_eps = self.calibrate(fun, x0, max_evals_grouped=self._max_evals_grouped)
#     512     else:
#     513         get_eta, get_eps = _validate_pert_and_learningrate(
#     514             self.perturbation, self.learning_rate
#     515         )
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\algorithms\optimizers\spsa.py:332, in SPSA.calibrate(loss, initial_point, c, stability_constant, target_magnitude, alpha, gamma, modelspace, max_evals_grouped)
#     329     pert = bernoulli_perturbation(dim)
#     330     points += [initial_point + c * pert, initial_point - c * pert]
# --> 332 losses = _batch_evaluate(loss, points, max_evals_grouped)
#     334 avg_magnitudes = 0
#     335 for i in range(steps):
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\algorithms\optimizers\spsa.py:691, in _batch_evaluate(function, points, max_evals_grouped)
#     687 def _batch_evaluate(function, points, max_evals_grouped):
#     688     # if the function cannot handle lists of points as input, cover this case immediately
#     689     if max_evals_grouped == 1:
#     690         # support functions with multiple arguments where the points are given in a tuple
# --> 691         return [
#     692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#     695     num_points = len(points)
#     697     # get the number of batches
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\algorithms\optimizers\spsa.py:692, in <listcomp>(.0)
#     687 def _batch_evaluate(function, points, max_evals_grouped):
#     688     # if the function cannot handle lists of points as input, cover this case immediately
#     689     if max_evals_grouped == 1:
#     690         # support functions with multiple arguments where the points are given in a tuple
#     691         return [
# --> 692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#     695     num_points = len(points)
#     697     # get the number of batches
#
# Input In [14], in f1(arr)
#       1 def f1(arr):
# ----> 2     counts1 = get_hopping_counts(arr)
#       3     counts2 = get_onsite_counts(arr)
#       4     counts1_new = new_counts(counts1)
#
# Input In [9], in get_hopping_counts(arr)
#       2 circ = get_hopping_circ(arr[0], arr[1])
#       3 backend = provider.get_backend('ibm_lagos')
# ----> 4 job = execute(circ, backend, shots = 8192)
#       5 counts = job.result().get_counts()
#       6 return counts
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\execute_function.py:294, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     291     experiments = pass_manager.run(experiments)
#     292 else:
#     293     # transpiling the circuits using given transpile options
# --> 294     experiments = transpile(
#     295         experiments,
#     296         basis_gates=basis_gates,
#     297         coupling_map=coupling_map,
#     298         backend_properties=backend_properties,
#     299         initial_layout=initial_layout,
#     300         seed_transpiler=seed_transpiler,
#     301         optimization_level=optimization_level,
#     302         backend=backend,
#     303     )
#     305 if schedule_circuit:
#     306     experiments = schedule(
#     307         circuits=experiments,
#     308         backend=backend,
#    (...)
#     311         method=scheduling_method,
#     312     )
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\compiler\transpiler.py:332, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     306 # Get transpile_args to configure the circuit transpilation job(s)
#     307 transpile_args = _parse_transpile_args(
#     308     circuits,
#     309     backend,
#    (...)
#     329     target,
#     330 )
# --> 332 _check_circuits_coupling_map(circuits, transpile_args, backend)
#     334 # Transpile circuits in parallel
#     335 circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#
# File ~\anaconda3\envs\vqe-research\lib\site-packages\qiskit\compiler\transpiler.py:379, in _check_circuits_coupling_map(circuits, transpile_args, backend)
#     376         max_qubits = backend.num_qubits
#     378 if max_qubits is not None and (num_qubits > max_qubits):
# --> 379     raise TranspilerError(
#     380         f"Number of qubits ({num_qubits}) in {circuit.name} "
#     381         f"is greater than maximum ({max_qubits}) in the coupling_map"
#     382     )
#
# TranspilerError: 'Number of qubits (8) in circuit-19 is greater than maximum (7) in the coupling_map'

# %%
# %store energy_diff1
# %store phi1
# %store theta1
# %store energy_diff2
# %store phi2
# %store theta2
# %store iterations1
# %store parameters1
# %store values1
# %store iterations2
# %store parameters2
# %store values2

# %%
print("Energy Difference: ", energy_diff1)
print("Phi: ", phi1)
print("Theta: ", theta1)
print("Phi: ", phi1%(2*pi))
print("Theta: ", theta1%(2*pi))

# %%
print("Energy Difference: ", energy_diff2)
print("Phi: ", phi2)
print("Theta: ", theta2)
print("Phi: ", phi2%(2*pi))
print("Theta: ", theta2%(2*pi))

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(iterations1, values1, label="SPSA")
plt.xlabel("Number of iterations", fontsize=14)
plt.ylabel("Value of Function", fontsize=14)
plt.grid()

plt.title("SPSA optimization", fontsize=16)
plt.legend(fontsize=14)
plt.show()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(iterations2, values2, label="SPSA")
plt.xlabel("Number of iterations", fontsize=14)
plt.ylabel("Value of Function", fontsize=14)
plt.grid()

plt.title("SPSA optimization", fontsize=16)
plt.legend(fontsize=14)
plt.show()
plt.show()
